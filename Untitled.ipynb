# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('less_big.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  beer_style_id                   beer_new_name    beer_style  \
# 0           0              0  Classic English-Style Pale Ale  English Pale
# 1           1              0  Classic English-Style Pale Ale  English Pale
# 2           4              0  Classic English-Style Pale Ale  English Pale
# 3           5              0  Classic English-Style Pale Ale  English Pale
# 4           6              0  Classic English-Style Pale Ale  English Pale
#
#    ibu_Min  ibu_Max  abv_Min  abv_Max  srm_Min  srm_Max  ...  review_time  \
# 0       20       40      4.5      5.5        5        5  ...   1294324816
# 1       20       40      4.5      5.5        5        5  ...   1283115229
# 2       20       40      4.5      5.5        5        5  ...   1130157499
# 3       20       40      4.5      5.5        5        5  ...   1314903858
# 4       20       40      4.5      5.5        5        5  ...   1311007143
#
# ...

# %%
df['review_time'] = pd.to_datetime(df['review_time'],unit='s')
# df['date'] = pd.to_datetime(df['date'],unit='s')

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df = df.drop(columns = ['beer_style_id', 'ibu_Min', 'abv_Min', 'abv_Max', 'srm_Min', 'og_Min'])

# %%
df = df.drop(columns = ['fg_Min', 'brewery_id'])

# %%
df.head()
# Out:
#                     beer_new_name    beer_style  ibu_Max  srm_Max  fg_Max  \
# 0  Classic English-Style Pale Ale  English Pale       40        5   1.016
# 1  Classic English-Style Pale Ale  English Pale       40        5   1.016
# 2  Classic English-Style Pale Ale  English Pale       40        5   1.016
# 3  Classic English-Style Pale Ale  English Pale       40        5   1.016
# 4  Classic English-Style Pale Ale  English Pale       40        5   1.016
#
#                  brewery_name         review_time  review_overall  \
# 0       Broad Ripple Brew Pub 2011-01-06 14:40:16             5.0
# 1       Broad Ripple Brew Pub 2010-08-29 20:53:49             4.5
# 2  Moon River Brewing Company 2005-10-24 12:38:19             4.5
# 3        Isle Of Skye Brewery 2011-09-01 19:04:18             3.5
# 4        Isle Of Skye Brewery 2011-07-18 16:39:03             3.5
#
#    review_aroma  review_appearance review_profilename  review_palate  \
# ...

# %%
df = df.groupby('review_profilename').filter(lambda x : len(x)>3)
Out[1743]:
# Out:
# (709198, 16)

# %%
df.shape
# Out:
# (709198, 16)
